# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/imersão python.xlsx",sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...  \
# 0           2.26         15.97      9.18      9.56  ...
# 1         -12.11         50.56      6.66      6.86  ...
# 2           7.64         77.55     40.81     42.34  ...
# 3          -4.89         18.85     51.89     53.17  ...
# 4          -3.66         20.70     36.37     37.32  ...
# ..           ...           ...       ...       ...  ...
# 76        -13.98        -32.72     10.70     11.08  ...
# 77        -23.55        -85.74      8.67      8.95  ...
# 78        -11.57         -2.77     56.04     58.90  ...
# 79        -12.29        -36.83      3.05      3.23  ...
# 80        -34.00        -25.44      5.51      6.02  ...
#
#    Valor Inicial (R$) (Ano)  Variação % (12M)  Valor Inicial (R$) (12M)  \
# 0                      9.29              0.16                      8.19
# 1                      7.76              0.51                      4.53
# 2                     38.98              0.78                     23.63
# 3                     55.63              0.19                     44.52
# 4                     38.51              0.21                     30.74
# ..                      ...               ...                       ...
# 76                    12.45             -0.33                     15.92
# 77                    11.38             -0.86                     61.01
# 78                    63.60             -0.03                     57.84
# 79                     3.50             -0.37                      4.86
# 80                     8.97             -0.25                      7.94
#
#     Quantidade de ações     Variação $  Resultado   Nome da empresa  \
# 0             515117391   241889725.40      Subiu          Usiminas
# 1            1110559345   177515970.30      Subiu     CSN Mineração
# 2            2379877655  2140059394.00      Subiu         Petrobras
# 3             683452836   722946282.70      Subiu            Suzano
# 4             187732538   138573955.10      Subiu      CPFL Energia
# ..                  ...            ...        ...               ...
# 76            533990587  -143635530.60     Desceu  Carrefour Brasil
# 77             94843047   -20810240.84     Desceu       Casas Bahia
# 78            853202347 -1807432634.00     Desceu          Localiza
# 79            525582771   -73557408.06     Desceu               CVC
# 80            198184909  -102993202.60     Desceu               GOL
#
#              Segmento  Idade         Cat_Idade
# 0          Siderurgia     59    Entre 50 e 100
# 1           Mineração     58    Entre 50 e 100
# 2            Petróleo     69    Entre 50 e 100
# 3    Papel e Celulose     96    Entre 50 e 100
# 4             Energia    109  Mais de 100 anos
# ..                ...    ...               ...
# 76             Varejo     46  Menos de 50 anos
# 77             Varejo     74    Entre 50 e 100
# 78  Aluguel de Carros     48  Menos de 50 anos
# 79            Turismo     49  Menos de 50 anos
# 80   Transporte Aéreo     21  Menos de 50 anos
#
# [81 rows x 28 columns]

# %%
df_total_acoes = pd.read_excel("/content/imersão python.xlsx",sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   235665566.00
# 1                      ALOS3   532616595.00
# 2                      ALPA4   176733968.00
# 3                      ABEV3  4394245879.00
# 4                      ARZZ3    62305891.00
# ..                       ...            ...
# 84                     VBBR3  1114412532.00
# 85                     WEGE3  1481593024.00
# 86                     YDUQ3   289347914.00
# 87  Quantidade Teórica Total 96372098181.00
# 88                   Redutor    17047850.79
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/imersão python.xlsx",sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/imersão python.xlsx",sheet_name="Chatgpt")
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade em Anos
# 0           Usiminas         Siderurgia             59
# 1      CSN Mineração          Mineração             58
# 2          Petrobras           Petróleo             69
# 3             Suzano   Papel e Celulose             96
# 4       CPFL Energia            Energia            109
# ..               ...                ...            ...
# 75  Carrefour Brasil             Varejo             46
# 76       Casas Bahia             Varejo             74
# 77          Localiza  Aluguel de Carros             48
# 78               CVC            Turismo             49
# 79               GOL   Transporte Aéreo             21
#
# [80 rows x 3 columns]

# %%
df_principal = df_principal [['Ativo','Data', 'Último (R$)','Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final','Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct']+1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial']) * df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 9 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 9 columns]

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 9 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs Resultado Ticker              Nome
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3     683452836   722946282.71     Subiu  SUZB3            Suzano
# 4     187732538   138573955.06     Subiu  CPFE3      CPFL Energia
# ..          ...            ...       ...    ...               ...
# 76    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 78    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 79    525582771   -73557408.06    Desceu  CVCB3               CVC
# 80    198184909  -102993202.62    Desceu  GOLL4               GOL
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# ..    ...        ...          ...          ...      ...            ...    ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs Resultado Ticker              Nome  \
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 4     683452836   722946282.71     Subiu  SUZB3            Suzano
# ..          ...            ...       ...    ...               ...
# 80    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 81     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 82    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 83    525582771   -73557408.06    Desceu  CVCB3               CVC
# 84    198184909  -102993202.62    Desceu  GOLL4               GOL
#
#      Nome da Empresa           Segmento  Idade em Anos
# 0           Usiminas         Siderurgia             59
# 1      CSN Mineração          Mineração             58
# 2          Petrobras           Petróleo             69
# 3          Petrobras           Petróleo             69
# 4             Suzano   Papel e Celulose             96
# ..               ...                ...            ...
# 80  Carrefour Brasil             Varejo             46
# 81       Casas Bahia             Varejo             74
# 82          Localiza  Aluguel de Carros             48
# 83               CVC            Turismo             49
# 84               GOL   Transporte Aéreo             21
#
# [85 rows x 15 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (fundação ou início de operações)' : 'Idade'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# ..    ...        ...          ...          ...      ...            ...    ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs Resultado Ticker              Nome  \
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 4     683452836   722946282.71     Subiu  SUZB3            Suzano
# ..          ...            ...       ...    ...               ...
# 80    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 81     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 82    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 83    525582771   -73557408.06    Desceu  CVCB3               CVC
# 84    198184909  -102993202.62    Desceu  GOLL4               GOL
#
#      Nome da Empresa           Segmento  Idade em Anos
# 0           Usiminas         Siderurgia             59
# 1      CSN Mineração          Mineração             58
# 2          Petrobras           Petróleo             69
# 3          Petrobras           Petróleo             69
# 4             Suzano   Papel e Celulose             96
# ..               ...                ...            ...
# 80  Carrefour Brasil             Varejo             46
# 81       Casas Bahia             Varejo             74
# 82          Localiza  Aluguel de Carros             48
# 83               CVC            Turismo             49
# 84               GOL   Transporte Aéreo             21
#
# [85 rows x 15 columns]

# %%
df_principal = df_principal.rename(columns={'Idade' : 'Ano_de_fundacao'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# ..    ...        ...          ...          ...      ...            ...    ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs Resultado Ticker              Nome  \
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 4     683452836   722946282.71     Subiu  SUZB3            Suzano
# ..          ...            ...       ...    ...               ...
# 80    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 81     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 82    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 83    525582771   -73557408.06    Desceu  CVCB3               CVC
# 84    198184909  -102993202.62    Desceu  GOLL4               GOL
#
#      Nome da Empresa           Segmento  Idade em Anos
# 0           Usiminas         Siderurgia             59
# 1      CSN Mineração          Mineração             58
# 2          Petrobras           Petróleo             69
# 3          Petrobras           Petróleo             69
# 4             Suzano   Papel e Celulose             96
# ..               ...                ...            ...
# 80  Carrefour Brasil             Varejo             46
# 81       Casas Bahia             Varejo             74
# 82          Localiza  Aluguel de Carros             48
# 83               CVC            Turismo             49
# 84               GOL   Transporte Aéreo             21
#
# [85 rows x 15 columns]

# %%
df_principal['Cat_Idade'] = df_principal['Idade em Anos'].apply(lambda x: 'Mais de 100 anos' if x > 100 else ('Menos de 50 anos' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# ..    ...        ...          ...          ...      ...            ...    ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtd_teorica    Variacao_rs Resultado Ticker              Nome  \
# 0     515117391   241889725.43     Subiu  USIM5          Usiminas
# 1    1110559345   177515970.30     Subiu  CMIN3     CSN Mineração
# 2    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 3    2379877655  2140059393.53     Subiu  PETR3         Petrobras
# 4     683452836   722946282.71     Subiu  SUZB3            Suzano
# ..          ...            ...       ...    ...               ...
# 80    533990587  -143635530.57    Desceu  CRFB3  Carrefour Brasil
# 81     94843047   -20810240.84    Desceu  BHIA3       Casas Bahia
# 82    853202347 -1807432634.46    Desceu  RENT3          Localiza
# 83    525582771   -73557408.06    Desceu  CVCB3               CVC
# 84    198184909  -102993202.62    Desceu  GOLL4               GOL
#
#      Nome da Empresa           Segmento  Idade em Anos         Cat_Idade
# 0           Usiminas         Siderurgia             59    Entre 50 e 100
# 1      CSN Mineração          Mineração             58    Entre 50 e 100
# 2          Petrobras           Petróleo             69    Entre 50 e 100
# 3          Petrobras           Petróleo             69    Entre 50 e 100
# 4             Suzano   Papel e Celulose             96    Entre 50 e 100
# ..               ...                ...            ...               ...
# 80  Carrefour Brasil             Varejo             46  Menos de 50 anos
# 81       Casas Bahia             Varejo             74    Entre 50 e 100
# 82          Localiza  Aluguel de Carros             48  Menos de 50 anos
# 83               CVC            Turismo             49  Menos de 50 anos
# 84               GOL   Transporte Aéreo             21  Menos de 50 anos
#
# [85 rows x 16 columns]

# %%
maior = df_principal['Variacao_rs'].max()
menor = df_principal['Variacao_rs'].min()
media = df_principal['Variacao_rs'].mean()
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()


print("Maior:", maior)
print("Menor:", menor)
print("Média:", media)
print("Média de quem subiu:", media_subiu)
print("Média de quem desceu:", media_desceu)
# Out:
# Maior: 4762926995.24809
# Menor: -1807432634.4595425
# Média: 229644360.94155562
# Média de quem subiu: 538720638.3614079
# Média de quem desceu: -181109141.75186712

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 5   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# 6   PRIO3 2024-01-26        45.69         1.98     0.02          44.80  PRIO3
# 7   PETR4 2024-01-26        39.96         1.73     0.02          39.28  PETR4
# 8   PETR4 2024-01-26        39.96         1.73     0.02          39.28  PETR4
# 9   VALE3 2024-01-26        69.50         1.66     0.02          68.37  VALE3
# 10  MULT3 2024-01-26        28.19         1.58     0.02          27.75  MULT3
# 11  ITUB4 2024-01-26        32.81         1.48     0.01          32.33  ITUB4
# 12  RDOR3 2024-01-26        27.56         1.43     0.01          27.17  RDOR3
# 13  BRKM5 2024-01-26        18.55         1.42     0.01          18.29  BRKM5
# 14  AZUL4 2024-01-26        14.27         1.42     0.01          14.07  AZUL4
# 15  RRRP3 2024-01-26        28.75         1.41     0.01          28.35  RRRP3
# 16  EQTL3 2024-01-26        35.32         1.34     0.01          34.85  EQTL3
# 17  CSNA3 2024-01-26        18.16         1.33     0.01          17.92  CSNA3
# 18  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52  YDUQ3
# 19  UGPA3 2024-01-26        28.31         1.28     0.01          27.95  UGPA3
# 20  MRVE3 2024-01-26         8.08         1.25     0.01           7.98  MRVE3
# 21  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25  ARZZ3
# 22  BBDC4 2024-01-26        15.52         1.04     0.01          15.36  BBDC4
# 23  BBDC4 2024-01-26        15.52         1.04     0.01          15.36  BBDC4
# 24  BEEF3 2024-01-26         7.19         0.98     0.01           7.12  BEEF3
# 25  PCAR3 2024-01-26         4.14         0.97     0.01           4.10  PCAR3
# 26  BRFS3 2024-01-26        14.61         0.96     0.01          14.47  BRFS3
# 27  VIVT3 2024-01-26        51.20         0.88     0.01          50.75  VIVT3
# 28  RAIL3 2024-01-26        22.64         0.84     0.01          22.45  RAIL3
# 29  CIEL3 2024-01-26         4.90         0.82     0.01           4.86  CIEL3
# 30  DXCO3 2024-01-26         7.81         0.77     0.01           7.75  DXCO3
# 31  TIMS3 2024-01-26        17.52         0.74     0.01          17.39  TIMS3
# 32  BRAP4 2024-01-26        23.22         0.73     0.01          23.05  BRAP4
# 33  LWSA3 2024-01-26         5.55         0.72     0.01           5.51  LWSA3
# 34  RECV3 2024-01-26        23.83         0.71     0.01          23.66  RECV3
# 35  ITSA4 2024-01-26        10.01         0.70     0.01           9.94  ITSA4
# 36  BBAS3 2024-01-26        56.97         0.68     0.01          56.59  BBAS3
# 37  RADL3 2024-01-26        26.16         0.61     0.01          26.00  RADL3
# 38  GOAU4 2024-01-26        10.08         0.59     0.01          10.02  GOAU4
# 39  CSAN3 2024-01-26        18.57         0.59     0.01          18.46  CSAN3
# 40  JBSS3 2024-01-26        24.34         0.57     0.01          24.20  JBSS3
# 41  MGLU3 2024-01-26         2.08         0.48     0.00           2.07  MGLU3
# 42  BBDC3 2024-01-26        13.75         0.36     0.00          13.70  BBDC3
# 43  BBDC3 2024-01-26        13.75         0.36     0.00          13.70  BBDC3
# 44  GGBR4 2024-01-26        21.84         0.27     0.00          21.78  GGBR4
# 45  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73  RAIZ4
# 46  CPLE6 2024-01-26        10.07         0.19     0.00          10.05  CPLE6
# 47  VAMO3 2024-01-26         8.18         0.12     0.00           8.17  VAMO3
#
#     Qtd_teorica   Variacao_rs Resultado Ticker                  Nome  \
# 0     515117391  241889725.43     Subiu  USIM5              Usiminas
# 1    1110559345  177515970.30     Subiu  CMIN3         CSN Mineração
# 2    2379877655 2140059393.53     Subiu  PETR3             Petrobras
# 3    2379877655 2140059393.53     Subiu  PETR3             Petrobras
# 4     683452836  722946282.71     Subiu  SUZB3                Suzano
# 5     187732538  138573955.06     Subiu  CPFE3          CPFL Energia
# 6     800010734  709687498.18     Subiu  PRIO3              PetroRio
# 7    4566445852 3103136291.22     Subiu  PETR4             Petrobras
# 8    4566445852 3103136291.22     Subiu  PETR4             Petrobras
# 9    4196924316 4762926995.25     Subiu  VALE3                  Vale
# 10    268505432  117732680.08     Subiu  MULT3             Multiplan
# 11   4801593832 2297591984.33     Subiu  ITUB4         Itaú Unibanco
# 12   1168230366  453917907.01     Subiu  RDOR3             Rede D'Or
# 13    265877867   69054317.64     Subiu  BRKM5               Braskem
# 14    327593725   65452205.55     Subiu  AZUL4                  Azul
# 15    235665566   94204643.35     Subiu  RRRP3          3R Petroleum
# 16   1095587251  511671895.45     Subiu  EQTL3    Equatorial Energia
# 17    600865451  143220991.46     Subiu  CSNA3  Siderúrgica Nacional
# 18    289347914   72295838.99     Subiu  YDUQ3                 YDUQS
# 19   1086411192  388705223.96     Subiu  UGPA3              Ultrapar
# 20    376187582   37525872.38     Subiu  MRVE3                   MRV
# 21     62305891   41021792.09     Subiu  ARZZ3                Arezzo
# 22   5146576868  822148336.41     Subiu  BBDC4        Banco Bradesco
# 23   5146576868  822148336.41     Subiu  BBDC4        Banco Bradesco
# 24    261036182   18214628.10     Subiu  BEEF3               Minerva
# 25    159430826    6340916.22     Subiu  PCAR3   Grupo Pão de Açúcar
# 26   1677525446  233045769.57     Subiu  BRFS3                   BRF
# 27    423091712  188965307.06     Subiu  VIVT3                  Vivo
# 28   1218352541  229771333.63     Subiu  RAIL3                  Rumo
# 29   1095462329   43657683.38     Subiu  CIEL3                 Cielo
# 30    302768240   18068446.61     Subiu  DXCO3                 Dexco
# 31    807896814  103972807.37     Subiu  TIMS3                   TIM
# 32    251003438   42238249.54     Subiu  BRAP4             Bradespar
# 33    393173139   15598886.65     Subiu  LWSA3               Locaweb
# 34    275005663   46201006.00     Subiu  RECV3        PetroRecôncavo
# 35   5372783971  373853994.88     Subiu  ITSA4                Itaúsa
# 36   1420949112  546752087.99     Subiu  BBAS3       Banco do Brasil
# 37   1275798515  202352473.74     Subiu  RADL3          RaiaDrogasil
# 38    660411219   39045606.94     Subiu  GOAU4    Metalúrgica Gerdau
# 39   1168097881  127229653.18     Subiu  CSAN3                 Cosan
# 40   1134986472  156573285.43     Subiu  JBSS3                   JBS
# 41   2867627068   28493619.27     Subiu  MGLU3        Magazine Luiza
# 42   1500728902   74019610.05     Subiu  BBDC3        Banco Bradesco
# 43   1500728902   74019610.05     Subiu  BBDC3        Banco Bradesco
# 44   1118525506   65779607.10     Subiu  GGBR4                Gerdau
# 45   1193047233   11571106.42     Subiu  RAIZ4                Raízen
# 46   1679335290   32069789.50     Subiu  CPLE6                 Copel
# 47    421383330    4131341.16     Subiu  VAMO3           Grupo Vamos
#
#          Nome da Empresa          Segmento  Idade em Anos         Cat_Idade
# 0               Usiminas        Siderurgia             59    Entre 50 e 100
# 1          CSN Mineração         Mineração             58    Entre 50 e 100
# 2              Petrobras          Petróleo             69    Entre 50 e 100
# 3              Petrobras          Petróleo             69    Entre 50 e 100
# 4                 Suzano  Papel e Celulose             96    Entre 50 e 100
# 5           CPFL Energia           Energia            109  Mais de 100 anos
# 6               PetroRio          Petróleo             11  Menos de 50 anos
# 7              Petrobras          Petróleo             69    Entre 50 e 100
# 8              Petrobras          Petróleo             69    Entre 50 e 100
# 9                   Vale         Mineração             79    Entre 50 e 100
# 10             Multiplan       Imobiliário             49  Menos de 50 anos
# 11         Itaú Unibanco        Financeiro             13  Menos de 50 anos
# 12             Rede D'Or             Saúde             51    Entre 50 e 100
# 13               Braskem           Química             20  Menos de 50 anos
# 14                  Azul  Transporte Aéreo             15  Menos de 50 anos
# 15          3R Petroleum          Petróleo              8  Menos de 50 anos
# 16    Equatorial Energia           Energia             22  Menos de 50 anos
# 17  Siderúrgica Nacional        Siderurgia             84    Entre 50 e 100
# 18                 YDUQS          Educação             53    Entre 50 e 100
# 19              Ultrapar           Energia             83    Entre 50 e 100
# 20                   MRV        Construção             43  Menos de 50 anos
# 21                Arezzo              Moda             49  Menos de 50 anos
# 22        Banco Bradesco        Financeiro             78    Entre 50 e 100
# 23        Banco Bradesco        Financeiro             78    Entre 50 e 100
# 24               Minerva         Alimentos             30  Menos de 50 anos
# 25   Grupo Pão de Açúcar            Varejo             72    Entre 50 e 100
# 26                   BRF         Alimentos             85    Entre 50 e 100
# 27                  Vivo  Telecomunicações             22  Menos de 50 anos
# 28                  Rumo        Transporte              9  Menos de 50 anos
# 29                 Cielo        Tecnologia             12  Menos de 50 anos
# 30                 Dexco        Tecnologia              5  Menos de 50 anos
# 31                   TIM  Telecomunicações             26  Menos de 50 anos
# 32             Bradespar        Financeiro             25  Menos de 50 anos
# 33               Locaweb        Tecnologia             23  Menos de 50 anos
# 34        PetroRecôncavo          Petróleo              8  Menos de 50 anos
# 35                Itaúsa        Financeiro             55    Entre 50 e 100
# 36       Banco do Brasil        Financeiro            213  Mais de 100 anos
# 37          RaiaDrogasil            Varejo            116  Mais de 100 anos
# 38    Metalúrgica Gerdau        Siderurgia            120  Mais de 100 anos
# 39                 Cosan           Energia             21  Menos de 50 anos
# 40                   JBS         Alimentos             68    Entre 50 e 100
# 41        Magazine Luiza            Varejo             64    Entre 50 e 100
# 42        Banco Bradesco        Financeiro             78    Entre 50 e 100
# 43        Banco Bradesco        Financeiro             78    Entre 50 e 100
# 44                Gerdau        Siderurgia            120  Mais de 100 anos
# 45                Raízen           Energia             11  Menos de 50 anos
# 46                 Copel           Energia             66    Entre 50 e 100
# 47           Grupo Vamos         Logística             22  Menos de 50 anos

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#             Segmento    Variacao_rs
# 0          Alimentos   407833683.09
# 1         Construção    37525872.38
# 2           Educação    72295838.99
# 3            Energia  1209821623.57
# 4         Financeiro  5052772209.67
# 5        Imobiliário   117732680.08
# 6          Logística     4131341.16
# 7          Mineração  4940442965.55
# 8               Moda    41021792.09
# 9   Papel e Celulose   722946282.71
# 10          Petróleo 11336484517.00
# 11           Química    69054317.64
# 12             Saúde   453917907.01
# 13        Siderurgia   489935930.93
# 14        Tecnologia    77325016.64
# 15  Telecomunicações   292938114.42
# 16        Transporte   229771333.63
# 17  Transporte Aéreo    65452205.55
# 18            Varejo   237187009.24

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 25858590641.35

# %%
fig = px.bar(df_analise_saldo, x = 'Resultado', y = 'Variacao_rs', text = 'Variacao_rs', title = 'Variação Reais por Resultado')
fig.update_traces(texttemplate='R$ %{text:,.2f}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0354293-1646-4877-8000-96794bd06e2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0354293-1646-4877-8000-96794bd06e2e")) {                    Plotly.newPlot(                        "c0354293-1646-4877-8000-96794bd06e2e",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,25858590641.34758],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,25858590641.34758],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:,.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":1 ...

# %%
fig = px.pie(df_analise_segmento, values='Variacao_rs', names='Segmento', title='Variação Reais das empresas valorizadas por Segmento de atuação')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df22be6f-1392-49e9-a8a8-76d17514dda2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df22be6f-1392-49e9-a8a8-76d17514dda2")) {                    Plotly.newPlot(                        "df22be6f-1392-49e9-a8a8-76d17514dda2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003eVariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimentos","Constru\u00e7\u00e3o","Educa\u00e7\u00e3o","Energia","Financeiro","Imobili\u00e1rio","Log\u00edstica","Minera\u00e7\u00e3o","Moda","Papel e Celulose","Petr\u00f3leo","Qu\u00edmica","Sa\u00fade","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Transporte","Transporte A\u00e9reo","Varejo"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,37525872.37728388,72295838.98616095,1209821623.5672965,5052772209.671483,117732680.0784251,4131341.15789051,4940442965.550434,41021792.09077153,722946282.7090385,11336484517.004236,69054317.63603853,453917907.01324,489935930.9283229,77325016.63608032,292938114.42357796,229771333.63468358,65452205.552800186,237187009.23736662],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode": ...

# %%
fig = px.bar(df_principal, x = 'Cat_Idade', y = 'Variacao_rs', text = 'Variacao_rs', title = 'Variação Reais por Faixe de existência da empresa')
fig.update_traces(texttemplate='R$ %{text:,.2f}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6401ecac-e957-4741-b43b-390d3250baf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6401ecac-e957-4741-b43b-390d3250baf8")) {                    Plotly.newPlot(                        "6401ecac-e957-4741-b43b-390d3250baf8",                        [{"alignmentgroup":"True","hovertemplate":"Cat_Idade=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[241889725.43155926,177515970.30234405,2140059393.5250204,2140059393.5250204,722946282.7090385,138573955.05629665,709687498.1779873,3103136291.216379,3103136291.216379,4762926995.24809,117732680.0784251,2297591984.325198,453917907.01324,69054317.63603853,65452205.552800186,94204643.3460701,511671895.45223427,143220991.46267557,72295838.98616095,388705223.95601785,37525872.37728388,41021792.09077153,822148336.4114583,822148336.4114583,18214628.100697115,6340916.223143544,233045769.5663398,188965307.05662104,229771333.63468358,43657683.37554085,18068446.60998324,103972807.36695692,42238249.53998644,15598886.650556229,46201005.997378685,373853994.88377655,546752087.993985,202352473.73982856,39045606.93544901,127229653.18222687,156573285.42541304,28493619.274394516,74019610.05281025,74019610.05281025,65779607.09863909,11571106.417007603,32069789.503513202,4131341.15789051,0.0,0.0,-4532537.188363132,-15725678.56411538,-9531377.745975774,-28492019.828986604,-23535874.329891067,-46851590.76171875,-118230410.43964578,-9468663.681704173,-36819552.33946995,-39743554.31491453,-17653966.51492794,-42561628.07917267,-48407328.154937305,-122247236.66863392,-21765343.021313515,-529460651.3402741,-9242203.65201259,-13667842.34040677,-42951047.21559978,-44345269.96582118,-21126374.325644854,-84945431.64294475,-233651943.49695757,-193280001.20849475,-268201195.08654764,-1173785666.3607426,-208257014.19914994,-79432785.73975119,-350645389.9146436,-351831366.6428625,-143635530.57495093,-20810240.843694936,-1807432634.4595425,-73557408.05509417,-102993202.61644287],"textposition":"auto","x":["Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Mais de 100 anos","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Mais de 100 anos","Mais de 100 anos","Mais de 100 anos","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Mais de 100 anos","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Mais de 100 anos","Entre 50 e 100","Entre 50 e 100","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Entre 50 e 100","Menos de 50 anos","Menos de 50 anos","Menos de 50 anos"],"xaxis":"x","y":[2418897 ...

# %%
# !pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import mplfinance as mpf
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
dados = yf.download('PETR4.SA',start='2023-01-01', end='2023-12-31')
dados
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-01-02  23.540001  23.809999  22.799999  22.920000  17.709478   78424700
# 2023-01-03  22.940001  23.100000  22.129999  22.340000  17.261332   96750300
# 2023-01-04  21.959999  23.590000  21.830000  23.049999  17.809923  129504000
# 2023-01-05  23.340000  24.040001  23.150000  23.879999  18.451233   73886000
# 2023-01-06  23.940001  24.320000  23.549999  23.740000  18.343061   51851500
# ...               ...        ...        ...        ...        ...        ...
# 2023-12-21  36.669998  36.680000  36.070000  36.389999  36.389999   30511900
# 2023-12-22  36.500000  36.799999  36.369999  36.740002  36.740002   31234700
# 2023-12-26  36.860001  37.369999  36.830002  37.330002  37.330002   23466800
# 2023-12-27  37.320000  37.430000  37.130001  37.360001  37.360001   19588500
# 2023-12-28  37.230000  37.360001  37.040001  37.240002  37.240002   21421900
#
# [248 rows x 6 columns]

# %%
dados.columns = ['Abertura','Maximo','Minimo','Fechamento', 'Fech_Ajust', 'Volume']

# %%
dados  = dados.rename_axis('Data')
dados
# Out:
#              Abertura     Maximo     Minimo  Fechamento  Fech_Ajust     Volume
# Data
# 2023-01-02  23.540001  23.809999  22.799999   22.920000   17.709478   78424700
# 2023-01-03  22.940001  23.100000  22.129999   22.340000   17.261332   96750300
# 2023-01-04  21.959999  23.590000  21.830000   23.049999   17.809923  129504000
# 2023-01-05  23.340000  24.040001  23.150000   23.879999   18.451233   73886000
# 2023-01-06  23.940001  24.320000  23.549999   23.740000   18.343061   51851500
# ...               ...        ...        ...         ...         ...        ...
# 2023-12-21  36.669998  36.680000  36.070000   36.389999   36.389999   30511900
# 2023-12-22  36.500000  36.799999  36.369999   36.740002   36.740002   31234700
# 2023-12-26  36.860001  37.369999  36.830002   37.330002   37.330002   23466800
# 2023-12-27  37.320000  37.430000  37.130001   37.360001   37.360001   19588500
# 2023-12-28  37.230000  37.360001  37.040001   37.240002   37.240002   21421900
#
# [248 rows x 6 columns]

# %%
dados['Fechamento'].plot(figsize=(10,6))
plt.title('Variação do preço por data',fontsize=16)
plt.legend(['Fechamento'])

# %%
df = dados.head(60).copy()

# Convertendo o índice em uma coluna de data
df['Data'] = df.index

# Convertendo as datas para o formato numérico de matplotlib
# Isso é necessário para que o Matplotlib possa plotar as datas corretamente no gráfico
df['Data'] = df['Data'].apply(mdates.date2num)

# %%
fig, ax = plt.subplots(figsize=(15,8))

width = 0.7

for i in range(len(df)):
    # Determinando a cor do candle
    # Se o preço de fechamento for maior que o de abertura, o candle é verde (a ação valorizou nesse dia).
    # Se for menor, o candle é vermelho (a ação desvalorizou).
    if df['Fechamento'].iloc[i] > df['Abertura'].iloc[i]:
        color = 'green'
    else:
        color = 'red'

    # Desenhando a linha vertical do candle (mecha)
    # Essa linha mostra os preços máximo (topo da linha) e mínimo (base da linha) do dia.
    # Usamos `ax.plot` para desenhar uma linha vertical.
    # [df['Data'].iloc[i], df['Data'].iloc[i]] define o ponto x da linha (a data), e [df['Mínimo'].iloc[i], df['Máximo'].iloc[i]] define a altura da linha.
    ax.plot([df['Data'].iloc[i], df['Data'].iloc[i]],
            [df['Minimo'].iloc[i], df['Maximo'].iloc[i]],
            color=color,
            linewidth=1)

    ax.add_patch(plt.Rectangle((df['Data'].iloc[i] - width/2, min(df['Abertura'].iloc[i], df['Fechamento'].iloc[i])),
                               width,
                               abs(df['Fechamento'].iloc[i] - df['Abertura'].iloc[i]),
                               facecolor=color))

df['MA7'] = df['Fechamento'].rolling(window=7).mean()
df['MA14'] = df['Fechamento'].rolling(window=14).mean()

# Plotando as médias móveis
ax.plot(df['Data'], df['MA7'], color='orange', label='Média Móvel 7 Dias')  # Média de 7 dias
ax.plot(df['Data'], df['MA14'], color='yellow', label='Média Móvel 14 Dias')  # Média de 14 dias
# Adicionando legendas para as médias móveis
ax.legend()

# Formatando o eixo x para mostrar as datas
# Configuramos o formato da data e a rotação para melhor legibilidade
ax.xaxis_date() #O método xaxis_date() é usado para dizer ao Matplotlib que as datas estão sendo usadas no eixo x
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

# Adicionando título e rótulos para os eixos x e y
plt.title("Gráfico de Candlestick - PETR4.SA com matplotlib")
plt.xlabel("Data")
plt.ylabel("Preço")

# Adicionando uma grade para facilitar a visualização dos valores
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %%
# Criando subplots
'''
"Primeiro, criamos uma figura que conterá nossos gráficos usando make_subplots.
Isso nos permite ter múltiplos gráficos em uma única visualização.
Aqui, teremos dois subplots: um para o gráfico de candlestick e outro para o volume de transações."

'''
fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                    vertical_spacing=0.1,
                    subplot_titles=('Candlesticks', 'Volume Transacionado'),
                    row_width=[0.2, 0.7])

'''
"No gráfico de candlestick, cada candle representa um dia de negociação,
mostrando o preço de abertura, fechamento, máximo e mínimo. Vamos adicionar este gráfico à nossa figura."
'''
# Adicionando o gráfico de candlestick
fig.add_trace(go.Candlestick(x=df.index,
                             open=df['Abertura'],
                             high=df['Maximo'],
                             low=df['Minimo'],
                             close=df['Fechamento'],
                             name='Candlestick'),
                             row=1, col=1)

# Adicionando as médias móveis
# Adicionamos também médias móveis ao mesmo subplot para análise de tendências
fig.add_trace(go.Scatter(x=df.index,
                         y=df['MA7'],
                         mode='lines',
                         name='MA7 - Média Móvel 7 Dias'),
                         row=1, col=1)

fig.add_trace(go.Scatter(x=df.index,
                         y=df['MA14'],
                         mode='lines',
                         name='MA14 - Média Móvel 14 Dias'),
                         row=1, col=1)

# Adicionando o gráfico de barras para o volume
# Em seguida, criamos um gráfico de barras para o volume de transações, que nos dá uma ideia da atividade de negociação naquele dia
fig.add_trace(go.Bar(x=df.index,
                     y=df['Volume'],
                     name='Volume'),
                     row=2, col=1)

# Atualizando layout
#Finalmente, configuramos o layout da figura, ajustando títulos, formatos de eixo e outras configurações para tornar o gráfico claro e legível.
fig.update_layout(yaxis_title='Preço',
                  xaxis_rangeslider_visible=False,  # Desativa o range slider
                  width=1100, height=600)

# Mostrando o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8de98df-655d-4bfa-87cc-c2b27855b520" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8de98df-655d-4bfa-87cc-c2b27855b520")) {                    Plotly.newPlot(                        "d8de98df-655d-4bfa-87cc-c2b27855b520",                        [{"close":[22.920000076293945,22.34000015258789,23.049999237060547,23.8799991607666,23.739999771118164,23.8700008392334,24.09000015258789,24.280000686645508,24.6299991607666,24.56999969482422,24.040000915527344,25.520000457763672,25.06999969482422,25.889999389648438,26.3700008392334,26.790000915527344,26.600000381469727,26.940000534057617,26.25,25.6200008392334,25.75,26.06999969482422,25.709999084472656,24.520000457763672,24.790000915527344,25.780000686645508,25.6200008392334,26.049999237060547,25.93000030517578,26.719999313354492,26.799999237060547,26.700000762939453,26.739999771118164,26.850000381469727,26.440000534057617,25.760000228881836,26.549999237060547,25.899999618530273,26.149999618530273,25.239999771118164,25.299999237060547,24.639999389648438,25.700000762939453,25.959999084472656,25.100000381469727,25.420000076293945,25.309999465942383,24.979999542236328,24.190000534057617,23.760000228881836,23.34000015258789,23.260000228881836,23.510000228881836,22.93000030517578,23.399999618530273,23.329999923706055,22.799999237060547,22.790000915527344,23.18000030517578,23.59000015258789],"high":[23.809999465942383,23.100000381469727,23.59000015258789,24.040000915527344,24.31999969482422,24.0,24.110000610351562,24.6200008392334,24.649999618530273,24.65999984741211,24.5,25.6200008392334,26.030000686645508,25.950000762939453,26.600000381469727,27.600000381469727,27.530000686645508,27.079999923706055,27.200000762939453,26.229999542236328,26.06999969482422,26.209999084472656,26.479999542236328,25.809999465942383,25.3799991607666,25.8700008392334,26.139999389648438,26.149999618530273,26.31999969482422,26.790000915527344,26.889999389648438,27.059999465942383,26.799999237060547,26.950000762939453,26.670000076293945,26.110000610351562,26.790000915527344,26.700000762939453,26.739999771118164,26.920000076293945,25.43000030517578,25.670000076293945,25.739999771118164,26.1200008392334,25.780000686645508,25.920000076293945,26.229999542236328,25.579999923706055,24.860000610351562,24.729999542236328,23.479999542236328,23.520000457763672,23.510000228881836,23.649999618530273,23.600000381469727,23.6200008392334,23.670000076293945,23.1299991607666,23.360000610351562,23.639999389648438],"low":[22.799999237060547,22.1299991607666,21.829999923706055,23.149999618530273,23.549999237060547,23.25,23.3700008392334,24.049999237060547,24.110000610351562,24.25,23.829999923706055,24.110000610351562,25.0,24.790000915527344,25.420000076293945,26.1299991607666,26.3700008392334,26.010000228881836,25.799999237060547,25.440000534057617,25.510000228881836,25.520000457763672,25.450000762939453,24.420000076293945,24.420000076293945,24.75,25.459999084472656,25.559999465942383,25.790000915527344,25.93000030517578,26.3700008392334,26.600000381469727,26.299999237060547,26.489999771118164,26.3700008392334,25.690000534057617,25.770000457763672,25.8700008392334,25.809999465942383,25.239999771118164,24.190000534057617,24.3700008392334,24.450000762939453,25.3700008392334,24.93000030517578,25.1299991607666,25.280000686645508,24.940000534057617,24.100000381469727,23.600000381469727,22.799999237060547,22.969999313354492,22.860000610351562,22.889999389648438,23.079999923706055,23.040000915527344,22.59000015258789,22.479999542236328,22.829999923706055,23.149999618530273],"name":"Candlestick","open":[23.540000915527344,22.940000534057617,21.959999084472656,23.34000015258789,23.940000534057617,23.5,23.950000762939453,24.14999961 ...

# %%
dados = yf.download('AAPL', start='2023-01-01', end='2023-12-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mpf.plot(dados.head(30), type='candle', figsize = (16,8), volume=True, mav=(7,14))

# %%
#Setando parâmetros iniciais
dados_apple = yf.download('AAPL', start='2023-01-01', end='2023-12-31')
dados_apple.columns = ['Abertura','Maximo','Minimo','Fechamento', 'Fech_Ajust', 'Volume']
dados_apple  = dados_apple.rename_axis('Data')
dados_apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               Abertura      Maximo      Minimo  Fechamento  Fech_Ajust  \
# Data
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.216301
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.497498
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.166641
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  128.735214
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.261612
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#                Volume
# Data
# 2023-01-03  112117500
# 2023-01-04   89113600
# 2023-01-05   80962700
# 2023-01-06   87754700
# 2023-01-09   70790800
# ...               ...
# 2023-12-22   37122800
# 2023-12-26   28919300
# 2023-12-27   48087700
# 2023-12-28   34049900
# 2023-12-29   42628800
#
# [250 rows x 6 columns]

# %%
# Plotando o preço de fechamento
dados_apple['Fechamento'].plot(figsize=(10,6))
plt.title('Variação do preço por data',fontsize=16)
plt.legend(['Fechamento'])

# Selecionando apenas os primeiros 60 dias para o gráfico de candlestick
d_apple = dados_apple.head(60).copy()

# Convertendo o índice em uma coluna de data
d_apple['Data'] = d_apple.index
d_apple['Data'] = d_apple['Data'].apply(mdates.date2num)

# %%
fig, ax = plt.subplots(figsize=(15,8))

width = 0.7

for i in range(len(d_apple)):
    # Determinando a cor do candle
    # Se o preço de fechamento for maior que o de abertura, o candle é verde (a ação valorizou nesse dia).
    # Se for menor, o candle é vermelho (a ação desvalorizou).
    if d_apple['Fechamento'].iloc[i] > d_apple['Abertura'].iloc[i]:
        color = 'green'
    else:
        color = 'red'

    # Desenhando a linha vertical do candle (mecha)
    ax.plot([d_apple['Data'].iloc[i], d_apple['Data'].iloc[i]],
            [d_apple['Minimo'].iloc[i], d_apple['Maximo'].iloc[i]],
            color=color,
            linewidth=1)

    ax.add_patch(plt.Rectangle((d_apple['Data'].iloc[i] - width/2, min(d_apple['Abertura'].iloc[i], d_apple['Fechamento'].iloc[i])),
                               width,
                               abs(d_apple['Fechamento'].iloc[i] - d_apple['Abertura'].iloc[i]),
                               facecolor=color))

d_apple['MA7'] = d_apple['Fechamento'].rolling(window=7).mean()
d_apple['MA14'] = d_apple['Fechamento'].rolling(window=14).mean()

# Plotando as médias móveis
ax.plot(d_apple['Data'], d_apple['MA7'], color='orange', label='Média Móvel 7 Dias')  # Média de 7 dias
ax.plot(d_apple['Data'], d_apple['MA14'], color='yellow', label='Média Móvel 14 Dias')  # Média de 14 dias
# Adicionando legendas para as médias móveis
ax.legend()

# Formatando o eixo x para mostrar as datas
# Configuramos o formato da data e a rotação para melhor legibilidade
ax.xaxis_date() #O método xaxis_date() é usado para dizer ao Matplotlib que as datas estão sendo usadas no eixo x
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

# Adicionando título e rótulos para os eixos x e y
plt.title("Gráfico de Candlestick - PETR4.SA com matplotlib")
plt.xlabel("Data")
plt.ylabel("Preço")

# Adicionando uma grade para facilitar a visualização dos valores
plt.grid(True)
plt.show()

# %% [markdown]
# **ÚLTIMA PARTE DA IMERSÃO**

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
# Baixar dados dos últimos quatro anos para uma ação específica
dados = yf.download("JNJ", start="2020-01-01",end="2023-12-31", progress=False)
dados = dados.reset_index()

# %%
# Divide os dados em: treino (até o final do primeiro semestre de 2023) e teste (segundo semestre de 2023)
dados_treino = dados[dados['Date'] < '2023-07-31']
dados_teste = dados[dados['Date'] >= '2023-07-31']

# %%
# Preparar os dados para o FBProphet
dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date': 'ds', 'Close': 'y'})

# %%
# Cria e treina o modelo
modelo = Prophet(weekly_seasonality=True, yearly_seasonality=True, daily_seasonality=False)

modelo.add_country_holidays(country_name='US')

modelo.fit(dados_prophet_treino)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3t8_ygrd/v1mnryne.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp3t8_ygrd/zbuc48qv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17117', 'data', 'file=/tmp/tmp3t8_ygrd/v1mnryne.json', 'init=/tmp/tmp3t8_ygrd/zbuc48qv.json', 'output', 'file=/tmp/tmp3t8_ygrd/prophet_modelw73ymuiz/prophet_model-20240329173035.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:30:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:30:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Criar datas futuras para previsão até o final de 2023
futuro = modelo.make_future_dataframe(periods=150)
previsao = modelo.predict(futuro)

# %%
# Plota os dados de treino, teste e previsões
plt.figure(figsize=(14, 8))
plt.plot(dados_treino['Date'], dados_treino['Close'], label='Dados de Treino', color='blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label='Dados Reais (Teste)', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='orange', linestyle='--')

plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--', label='Início da Previsão')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.title('Previsão de Preço de Fechamento vs Dados Reais')
plt.legend()
plt.show()
